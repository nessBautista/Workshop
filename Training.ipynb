# %%
from IPython.display import Image
Im = Image(filename='images/vector.png')
Im

# %%
errorsImg = Image(filename='images/errors.png')
errorsImg

# %%
sqErrorsImg = Image(filename='images/sqErrors.jpg')
sqErrorsImg
